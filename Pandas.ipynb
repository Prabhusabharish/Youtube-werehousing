# %% [markdown]
# **PANDAS IMPORT**

# %%
import pandas as pd #adf

# %%
df=pd.read_csv("/content/products.csv")

# %%
df
# Out:
#            product  quantity  price                                description
# 0           Apples         3    2.5                            Sweet and juicy
# 1          Bananas         4    1.5                 A good source of potassium
# 2            Bread         2    2.0                            Soft and fluffy
# 3             Eggs        12    3.0                   A good source of protein
# 4             Milk         1    3.5                   A good source of calcium
# 5           Yogurt         2    2.0                A good source of probiotics
# 6   Chicken breast         2    5.0                 A lean and healthy protein
# 7      Ground beef         1    4.0                        A versatile protein
# 8         Broccoli         1    3.0                  A nutrient-rich vegetable
# 9          Carrots         1    2.0                 A good source of vitamin A
# 10        Potatoes         5    2.0                      A versatile vegetable
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['product', 'quantity', 'price', 'description'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
df.values
# Out:
# array([['Apples', 3, 2.5, 'Sweet and juicy'],
#        ['Bananas', 4, 1.5, 'A good source of potassium'],
#        ['Bread', 2, 2.0, 'Soft and fluffy'],
#        ['Eggs', 12, 3.0, 'A good source of protein'],
#        ['Milk', 1, 3.5, 'A good source of calcium'],
#        ['Yogurt', 2, 2.0, 'A good source of probiotics'],
#        ['Chicken breast', 2, 5.0, 'A lean and healthy protein'],
#        ['Ground beef', 1, 4.0, 'A versatile protein'],
#        ['Broccoli', 1, 3.0, 'A nutrient-rich vegetable'],
#        ['Carrots', 1, 2.0, 'A good source of vitamin A'],
#        ['Potatoes', 5, 2.0, 'A versatile vegetable'],
#        ['Onions', 2, 1.5, 'A flavorful vegetable'],
#        ['Tomatoes', 4, 2.0, 'A versatile fruit/vegetable'],
#        ['Rice', 2, 3.0, 'A good source of carbohydrates'],
#        ['Pasta', 2, 2.0, 'A versatile carbohydrate'],
#        ['Cereal', 2, 2.0, 'A quick and easy breakfast'],
#        ['Peanut butter', 1, 3.0,
# ...

# %%
df.shape # 20 Rows and 4 columns
# Out:
# (20, 4)

# %%
df.head() # Only show for first 5 rows Its is a default Value (5 rows).
# Out:
#    product  quantity  price                 description
# 0   Apples         3    2.5             Sweet and juicy
# 1  Bananas         4    1.5  A good source of potassium
# 2    Bread         2    2.0             Soft and fluffy
# 3     Eggs        12    3.0    A good source of protein
# 4     Milk         1    3.5    A good source of calcium

# %%
df.head(3) # Only get 3 rows (3)
# Out:
#    product  quantity  price                 description
# 0   Apples         3    2.5             Sweet and juicy
# 1  Bananas         4    1.5  A good source of potassium
# 2    Bread         2    2.0             Soft and fluffy

# %%
df.tail()# Only show for last 5 rows Its is a default Value (5 rows).
# Out:
#           product  quantity  price                                description
# 15         Cereal         2    2.0                 A quick and easy breakfast
# 16  Peanut butter         1    3.0  A good source of protein and healthy fats
# 17          Jelly         1    2.0                             A sweet spread
# 18         Coffee         1    4.0                         A popular beverage
# 19            Tea         1    3.0                   Another popular beverage

# %%
df.tail(9) # Only show for last 9 rows Its is a default Value (5 rows).
# Out:
#           product  quantity  price                                description
# 11         Onions         2    1.5                      A flavorful vegetable
# 12       Tomatoes         4    2.0                A versatile fruit/vegetable
# 13           Rice         2    3.0             A good source of carbohydrates
# 14          Pasta         2    2.0                   A versatile carbohydrate
# 15         Cereal         2    2.0                 A quick and easy breakfast
# 16  Peanut butter         1    3.0  A good source of protein and healthy fats
# 17          Jelly         1    2.0                             A sweet spread
# 18         Coffee         1    4.0                         A popular beverage
# 19            Tea         1    3.0                   Another popular beverage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product      20 non-null     object
#  1   quantity     20 non-null     int64
#  2   price        20 non-null     float64
#  3   description  20 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 768.0+ bytes

# %% [markdown]
# **ACCESING**

# %%
df['product']
# Out:
# 0             Apples
# 1            Bananas
# 2              Bread
# 3               Eggs
# 4               Milk
# 5             Yogurt
# 6     Chicken breast
# 7        Ground beef
# 8           Broccoli
# 9            Carrots
# 10          Potatoes
# 11            Onions
# 12          Tomatoes
# 13              Rice
# 14             Pasta
# 15            Cereal
# 16     Peanut butter
# 17             Jelly
# 18            Coffee
# 19               Tea
# Name: product, dtype: object

# %%
df['quantity']
# Out:
# 0      3
# 1      4
# 2      2
# 3     12
# 4      1
# 5      2
# 6      2
# 7      1
# 8      1
# 9      1
# 10     5
# 11     2
# 12     4
# 13     2
# 14     2
# 15     2
# 16     1
# 17     1
# 18     1
# 19     1
# Name: quantity, dtype: int64

# %%
type(df['product'])
# Out:
# pandas.core.series.Series

# %%
df[['product', 'quantity']]
# Out:
#            product  quantity
# 0           Apples         3
# 1          Bananas         4
# 2            Bread         2
# 3             Eggs        12
# 4             Milk         1
# 5           Yogurt         2
# 6   Chicken breast         2
# 7      Ground beef         1
# 8         Broccoli         1
# 9          Carrots         1
# 10        Potatoes         5
# 11          Onions         2
# 12        Tomatoes         4
# 13            Rice         2
# 14           Pasta         2
# 15          Cereal         2
# 16   Peanut butter         1
# 17           Jelly         1
# 18          Coffee         1
# 19             Tea         1

# %%
type([['product', 'quantity']])
# Out:
# list

# %%
df[['product', 'price', 'quantity']]
# Out:
#            product  price  quantity
# 0           Apples    2.5         3
# 1          Bananas    1.5         4
# 2            Bread    2.0         2
# 3             Eggs    3.0        12
# 4             Milk    3.5         1
# 5           Yogurt    2.0         2
# 6   Chicken breast    5.0         2
# 7      Ground beef    4.0         1
# 8         Broccoli    3.0         1
# 9          Carrots    2.0         1
# 10        Potatoes    2.0         5
# 11          Onions    1.5         2
# 12        Tomatoes    2.0         4
# 13            Rice    3.0         2
# 14           Pasta    2.0         2
# 15          Cereal    2.0         2
# 16   Peanut butter    3.0         1
# 17           Jelly    2.0         1
# 18          Coffee    4.0         1
# 19             Tea    3.0         1

# %%
type(df[['product', 'price', 'quantity']])
# Out:
# pandas.core.frame.DataFrame

# %%
# using I lock always pass index
df.iloc[0:6] # slicing 0th rows to 6 nos rows
# Out:
#    product  quantity  price                  description
# 0   Apples         3    2.5              Sweet and juicy
# 1  Bananas         4    1.5   A good source of potassium
# 2    Bread         2    2.0              Soft and fluffy
# 3     Eggs        12    3.0     A good source of protein
# 4     Milk         1    3.5     A good source of calcium
# 5   Yogurt         2    2.0  A good source of probiotics

# %%
df.iloc[0] # slicing 0th rows.
# Out:
# product                 Apples
# quantity                     3
# price                      2.5
# description    Sweet and juicy
# Name: 0, dtype: object

# %%
df.iloc[1:10:2] # slicing staer 1st row to 10th rows and 2 slicing.
# Out:
#        product  quantity  price                  description
# 1      Bananas         4    1.5   A good source of potassium
# 3         Eggs        12    3.0     A good source of protein
# 5       Yogurt         2    2.0  A good source of probiotics
# 7  Ground beef         1    4.0          A versatile protein
# 9      Carrots         1    2.0   A good source of vitamin A

# %%
df.iloc[1:20:2]
# Out:
#         product  quantity  price                     description
# 1       Bananas         4    1.5      A good source of potassium
# 3          Eggs        12    3.0        A good source of protein
# 5        Yogurt         2    2.0     A good source of probiotics
# 7   Ground beef         1    4.0             A versatile protein
# 9       Carrots         1    2.0      A good source of vitamin A
# 11       Onions         2    1.5           A flavorful vegetable
# 13         Rice         2    3.0  A good source of carbohydrates
# 15       Cereal         2    2.0      A quick and easy breakfast
# 17        Jelly         1    2.0                  A sweet spread
# 19          Tea         1    3.0        Another popular beverage

# %%
df.iloc[1:20]
# Out:
#            product  quantity  price                                description
# 1          Bananas         4    1.5                 A good source of potassium
# 2            Bread         2    2.0                            Soft and fluffy
# 3             Eggs        12    3.0                   A good source of protein
# 4             Milk         1    3.5                   A good source of calcium
# 5           Yogurt         2    2.0                A good source of probiotics
# 6   Chicken breast         2    5.0                 A lean and healthy protein
# 7      Ground beef         1    4.0                        A versatile protein
# 8         Broccoli         1    3.0                  A nutrient-rich vegetable
# 9          Carrots         1    2.0                 A good source of vitamin A
# 10        Potatoes         5    2.0                      A versatile vegetable
# 11          Onions         2    1.5                      A flavorful vegetable
# ...

# %%
df.iloc[0:6,2]
# Out:
# 0    2.5
# 1    1.5
# 2    2.0
# 3    3.0
# 4    3.5
# 5    2.0
# Name: price, dtype: float64

# %%
df.iloc[3,0:2] # slicing either rows and columns.
# Out:
# product     Eggs
# quantity      12
# Name: 3, dtype: object

# %%
df.iloc[0:6,3] # # particular rows(0) to columns(6) values.
# Out:
# 0                Sweet and juicy
# 1     A good source of potassium
# 2                Soft and fluffy
# 3       A good source of protein
# 4       A good source of calcium
# 5    A good source of probiotics
# Name: description, dtype: object

# %%
df.iloc[4,0] # particular rows(4) and columns(0) value.
# Out:
# 'Milk'

# %%
df.iloc[8,3] # particular rows(8) and columns(3) value.
# Out:
# 'A nutrient-rich vegetable'

# %%
# to get more columns and rows
df.iloc[[0,3,7], [0,1,2]] # first rows(0),(3),(7) and columns (0),(1),(2)
# Out:
#        product  quantity  price
# 0       Apples         3    2.5
# 3         Eggs        12    3.0
# 7  Ground beef         1    4.0

# %%
# using LOC allows passing column names too
df.loc[10:14:2]
# Out:
#      product  quantity  price                  description
# 10  Potatoes         5    2.0        A versatile vegetable
# 12  Tomatoes         4    2.0  A versatile fruit/vegetable
# 14     Pasta         2    2.0     A versatile carbohydrate

# %%
df.loc[10, 'product'] # using LOC allows passing column names too
# Out:
# 'Potatoes'

# %%
df.loc[10:14, 'product': 'price'] # particular rows and column
# Out:
#      product  quantity  price
# 10  Potatoes         5    2.0
# 11    Onions         2    1.5
# 12  Tomatoes         4    2.0
# 13      Rice         2    3.0
# 14     Pasta         2    2.0

# %%
df.loc[[0,1,2,3],['product','price']] # # particular rows and column
# Out:
#    product  price
# 0   Apples    2.5
# 1  Bananas    1.5
# 2    Bread    2.0
# 3     Eggs    3.0

# %%
df['product']=='Apples' # bool data type reply
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: product, dtype: bool

# %%
df.loc[df['product']=='Apples']
# Out:
#   product  quantity  price      description
# 0  Apples         3    2.5  Sweet and juicy

# %%
df.loc[df['product']=='Jelly']
# Out:
#    product  quantity  price     description
# 17   Jelly         1    2.0  A sweet spread

# %%
df.loc[df['price']<=3]
# Out:
#           product  quantity  price                                description
# 0          Apples         3    2.5                            Sweet and juicy
# 1         Bananas         4    1.5                 A good source of potassium
# 2           Bread         2    2.0                            Soft and fluffy
# 3            Eggs        12    3.0                   A good source of protein
# 5          Yogurt         2    2.0                A good source of probiotics
# 8        Broccoli         1    3.0                  A nutrient-rich vegetable
# 9         Carrots         1    2.0                 A good source of vitamin A
# 10       Potatoes         5    2.0                      A versatile vegetable
# 11         Onions         2    1.5                      A flavorful vegetable
# 12       Tomatoes         4    2.0                A versatile fruit/vegetable
# 13           Rice         2    3.0             A good source of carbohydrates
# ...

# %%
df.loc[(df['price']<=3) & (df['quantity']>2)] # two True is exceptable
# Out:
#      product  quantity  price                  description
# 0     Apples         3    2.5              Sweet and juicy
# 1    Bananas         4    1.5   A good source of potassium
# 3       Eggs        12    3.0     A good source of protein
# 10  Potatoes         5    2.0        A versatile vegetable
# 12  Tomatoes         4    2.0  A versatile fruit/vegetable

# %%
df.loc[(df['price']<=3) | (df['quantity']>2)] # One True is exceptable
# Out:
#           product  quantity  price                                description
# 0          Apples         3    2.5                            Sweet and juicy
# 1         Bananas         4    1.5                 A good source of potassium
# 2           Bread         2    2.0                            Soft and fluffy
# 3            Eggs        12    3.0                   A good source of protein
# 5          Yogurt         2    2.0                A good source of probiotics
# 8        Broccoli         1    3.0                  A nutrient-rich vegetable
# 9         Carrots         1    2.0                 A good source of vitamin A
# 10       Potatoes         5    2.0                      A versatile vegetable
# 11         Onions         2    1.5                      A flavorful vegetable
# 12       Tomatoes         4    2.0                A versatile fruit/vegetable
# 13           Rice         2    3.0             A good source of carbohydrates
# ...

# %%
df1=pd.read_csv("/content/products_noheader.csv")

# %%
df1.columns
# Out:
# Index(['Apples', '3', '2.5', 'Sweet and juicy'], dtype='object')

# %%
df1=pd.read_csv("/content/products_noheader.csv")

# %%
df1=pd.read_csv("/content/products_noheader.csv", header=None, names=['product','quality','description'])

# %%
df1=pd.read_csv("/content/products_noheader.csv",comment='#', names=['product','quality','description'])

# %%
df1.columns
# Out:
# Index(['product', 'quality', 'description'], dtype='object')
